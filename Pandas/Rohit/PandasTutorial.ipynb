# %% [markdown]
# # Pandas tutorial:
# West Portland Data Science Club
#
# Created by Rohit Malshe

# %% [markdown]
# **Create Data**
#
# **Get Data**
#
# **Prepare Data**
#
# **Analyze Data**
#
# **Present Data**

# %% [markdown]
# # iPython Notebook fundamentals
# http://ipython.org/ipython-doc/dev/notebook/index.html

# %% [markdown]
# Following imports will work for a basic datascience project workbook.

# %%
import smtplib
from matplotlib import style
import seaborn as sns
sns.set(style='ticks', palette='RdBu')
import pandas as pd
import numpy as np
import time
import datetime 
# %matplotlib inline
import matplotlib.pyplot as plt
pd.options.display.max_colwidth = 1000
from time import gmtime, strftime
Time_now = strftime("%Y-%m-%d %H:%M:%S", gmtime())
import timeit
start = timeit.default_timer()
pd.options.display.max_rows = 100
import random
path = 'C:/Users/rmalshe/Desktop/CareerDevelopment/PROGRAMMING_LANGUAGES/iPythonNotebooks/UGLY_DATA/'

# %% [markdown]
# # Pandas has a lot of functions ~ 150 or so:
# It always beats me to my imagination. So before you write a lengthy code, check out on Google and Stack Overflow what pandas' inherent capabilities are

# %% [markdown]
# pd.compat
#
# pd.computation
#
# pd.concat
#
# pd.core
#
# pd.crosstab
#
# pd.cut
#
# pd.Categorical
#
# pd.CategoricalIndex
#
#
#
# pd.date_range
#
# pd.datetime
#
# pd.datetools
#
# pd.dependency
#
# pd.describe_option
#
# pd.DataFrame
#
# pd.DateOffset
#
# pd.DatetimeIndex
#
#
#
# pd.eval
#
#
# pd.ewma
#
# pd.ewmcorr
#
# pd.ewmcov
#
# pd.ewmstd
#
#
# pd.ewmvar
#
# pd.ewmvol
#
# **Rolling averages**
#
# pd.expanding_apply
#
# pd.expanding_corr
#
# pd.expanding_count
#
# pd.expanding_kurt
#
# pd.expanding_max
#
# pd.expanding_mean
#
# pd.expanding_median
#
# pd.expanding_min
#
# pd.expanding_min
#
# pd.expanding_quantile
#
# pd.expanding_skew
#
# pd.expanding_std
#
# pd.expanding_sum
#
# pd.expanding_var
#
# pd.ExcelFile
#
#
# pd.ExcelWriter
#
# pd.Expr
#
#
# pd.factorize
#
# pd.fama_macbeth
#
# pd.formats
#
# pd.Float64Index
#
#
#
# pd.get_dummies
#
# pd.get_option
#
#
# pd.get_store
#
# pd.Grouper
#
#
#
# pd.hard_dependencies
#
# pd.hashtable
#
#
# pd.HDFStore
#
#
#
# pd.index
#
# pd.indexes
#
# pd.infer_freq
#
# pd.info
#
#
# pd.io
#
# pd.isnull
#
#
#
# pd.Index
#
# pd.IndexSlice
#
# pd.Int64Index
#
#
#
# pd.json
#
#
#
#
# pd.lib
#
# pd.lreshape
#
#
#
# pd.match
#
# pd.melt
#
# pd.merge
#
#
# pd.missing_dependencies
#
# pd.msgpack
#
# pd.MultiIndex
#
#
#
# pd.notnull
#
# pd.np
#
# pd.NaT
#
#
#
# pd.offsets
#
#
# pd.ols
#
# pd.option_context
#
# pd.options
#
# pd.ordered_merge
#
#
#
# pd.pandas
#
# pd.parser
#
# pd.period_range
#
# pd.pivot
#
# pd.pivot_table
#
# pd.pnow
#
# pd.Panel
#
# pd.Panel4D
#
# pd.Period
#
#
# pd.PeriodIndex
#
#
#
# pd.qcut
#
#
#
# pd.read_clipboard
#
# pd.read_csv
#
# pd.read_excel
#
# pd.read_fwf
#
# pd.read_gbq
#
# pd.read_hdf
#
# pd.read_html
#
# pd.read_json
#
# pd.read_msgpack
#
# pd.read_pickle
#
# pd.read_sas
#
# pd.read_sql
#
# pd.read_sql_query
#
# pd.read_sql_table
#
# pd.read_stata
#
# pd.read_table
#
# pd.RangeIndex
#
#
#
# pd.scatter_matrix
#
# pd.set_eng_float_format
#
# pd.set_option
#
# pd.show_versions
#
# pd.sparse
#
# pd.stats
#
# pd.Series
#
# pd.SparseArray
#
# pd.SparseDataFrame
#
# pd.SparseList
#
# pd.SparseSeries
#
# pd.SparsePanel
#
# pd.SparseTimeSeries
#
#
#
# pd.test
#
# pd.timedelta_range
#
# pd.to_datetime
#
# pd.to_msgpack
#
# pd.to_numeric
#
# pd.to_pickle
#
# pd.to_timedelta
#
# pd.tools
#
# pd.tseries
#
# pd.tslib
#
# pd.types
#
#
#
# pd.Term
#
# pd.TimeGrouper
#
# pd.TimeSeries
#
# pd.Timedelta
#
# pd.TimedeltaIndex
#
# pd.Timestamp
#
#
#
# pd.unique
#
# pd.util

# %% [markdown]
# # Pandas essentials

# %% [markdown]
# 10 Minutes to Pandas:

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20170128', periods=6)

# %% [markdown]
# This is the most important command in Pandas. pd.DataFrame() The first thing one should try to do is to get their data as a Pandas Dataframe. Once the data are represented as Pandas dataframe, things look very much like excel, and also work somewhat similar to excel. In addition, a lot of transformations are then possible that are faster and better than excel.

# %%
pd.DataFrame?

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2017-01-28  1.132706 -0.144552 -0.289030  0.451917
# 2017-01-29 -1.340943 -0.482995  0.780168  0.040512
# 2017-01-30  0.449256  0.785966  2.456271  0.028777
# 2017-01-31 -1.270629  0.497702 -0.342312 -0.481708
# 2017-02-01  1.185940 -1.724346 -1.449367 -0.434060
# 2017-02-02 -0.561221 -0.110831  1.449379 -0.673854

# %%
df = pd.DataFrame({'A' : [0.9, 1.0, 1.1, 1.2],
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' ,
                    'G' : [1.9, 2.0, 3.1, 4.2] })

# %%
df
# Out:
#      A          B    C  D      E    F    G
# 0  0.9 2013-01-02  1.0  3   test  foo  1.9
# 1  1.0 2013-01-02  1.0  3  train  foo  2.0
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1
# 3  1.2 2013-01-02  1.0  3  train  foo  4.2

# %% [markdown]
# Finding properties of your dataframe object. Usually one should try to keep df objects with obvious names such as ~ df, df1, df2, etc. Then one can concatenate more details on to them for example ~ df_sample, df_small, df_one, df_set etc.

# %%
df.index #dataframes follow an index.
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df.describe() #describe
# Out:
#               A    C    D         G
# count  4.000000  4.0  4.0  4.000000
# mean   1.050000  1.0  3.0  2.800000
# std    0.129099  0.0  0.0  1.080123
# min    0.900000  1.0  3.0  1.900000
# 25%    0.975000  1.0  3.0  1.975000
# 50%    1.050000  1.0  3.0  2.550000
# 75%    1.125000  1.0  3.0  3.375000
# max    1.200000  1.0  3.0  4.200000

# %%
df.T #Transpose
# Out:
#                      0                    1                    2  \
# A                  0.9                    1                  1.1
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                    1                    1                    1
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
# G                  1.9                    2                  3.1
#
#                      3
# A                  1.2
# B  2013-01-02 00:00:00
# C                    1
# D                    3
# E                train
# F                  foo
# G                  4.2

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#      G    F      E  D    C          B    A
# 0  1.9  foo   test  3  1.0 2013-01-02  0.9
# 1  2.0  foo  train  3  1.0 2013-01-02  1.0
# 2  3.1  foo   test  3  1.0 2013-01-02  1.1
# 3  4.2  foo  train  3  1.0 2013-01-02  1.2

# %%
df.sort_values(by='B')
# Out:
#      A          B    C  D      E    F    G
# 0  0.9 2013-01-02  1.0  3   test  foo  1.9
# 1  1.0 2013-01-02  1.0  3  train  foo  2.0
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1
# 3  1.2 2013-01-02  1.0  3  train  foo  4.2

# %%
df['A'] # can also be done by df.A
# Out:
# 0    0.9
# 1    1.0
# 2    1.1
# 3    1.2
# Name: A, dtype: float64

# %%
df[0:3] # slices via rows
# Out:
#      A          B    C  D      E    F    G
# 0  0.9 2013-01-02  1.0  3   test  foo  1.9
# 1  1.0 2013-01-02  1.0  3  train  foo  2.0
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1

# %%
columns = ['A', 'B']
df.loc[:,columns] 
#colon takes all rows. 
# If numbers are put on the sides of the colon, fewer rows are chosen. 
# Columns are given in square brackets
# Out:
#      A          B
# 0  0.9 2013-01-02
# 1  1.0 2013-01-02
# 2  1.1 2013-01-02
# 3  1.2 2013-01-02

# %%
df.loc[1:3, ['A', 'B', 'E']]
# Out:
#      A          B      E
# 1  1.0 2013-01-02  train
# 2  1.1 2013-01-02   test
# 3  1.2 2013-01-02  train

# %%
df.iloc[3]
# Out:
# A                    1.2
# B    2013-01-02 00:00:00
# C                      1
# D                      3
# E                  train
# F                    foo
# G                    4.2
# Name: 3, dtype: object

# %%
df.iloc[2:3,0:2]
# Out:
#      A          B
# 2  1.1 2013-01-02

# %%
df.iloc[1:3,:] #getting
# Out:
#      A          B    C  D      E    F    G
# 1  1.0 2013-01-02  1.0  3  train  foo  2.0
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1

# %%
df.iloc[1,1] # getting specific location from the dataframe
# Out:
# Timestamp('2013-01-02 00:00:00')

# %%
df[df.A > 1.01]
# Out:
#      A          B    C  D      E    F    G
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1
# 3  1.2 2013-01-02  1.0  3  train  foo  4.2

# %%
df2 = df.copy()

# %%
df2['H'] = ['one', 'one','two','three']

# %%
df2
# Out:
#      A          B    C  D      E    F    G      H
# 0  0.9 2013-01-02  1.0  3   test  foo  1.9    one
# 1  1.0 2013-01-02  1.0  3  train  foo  2.0    one
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1    two
# 3  1.2 2013-01-02  1.0  3  train  foo  4.2  three

# %%
df2[df2['H'].isin(['two','three'])] # isin function is very handy to select specific rows where one column carries some text
# Out:
#      A          B    C  D      E    F    G      H
# 2  1.1 2013-01-02  1.0  3   test  foo  3.1    two
# 3  1.2 2013-01-02  1.0  3  train  foo  4.2  three

# %%
df2.shape 
#df2.shape[0]
# Out:
# (4, 8)

# %%
df2[~df2['H'].isin(['two'])]
# Out:
#      A          B    C  D      E    F    G      H
# 0  0.9 2013-01-02  1.0  3   test  foo  1.9    one
# 1  1.0 2013-01-02  1.0  3  train  foo  2.0    one
# 3  1.2 2013-01-02  1.0  3  train  foo  4.2  three

# %%
pd.isnull(df2)
# Out:
#        A      B      C      D      E      F      G      H
# 0  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False

# %% [markdown]
# # Concat, Merge, Join
# Follow this web link to see how various types of merge operations can be carried out. The schematics will show you how to achieve this easily:
# http://pandas.pydata.org/pandas-docs/stable/merging.html

# %%
df = pd.DataFrame(np.random.randn(10, 4))
X, Y, Z = [df[:3], df[3:7], df[7:]]

# %%
X, Y, Z
# Out:
# (          0         1         2         3
#  0  0.133433 -1.141337 -1.307757 -0.846003
#  1 -0.908109 -0.412874  2.360426  0.521012
#  2 -2.403655 -0.264082  0.264862  0.555531,
#            0         1         2         3
#  3 -0.235506  1.032290 -0.307916  0.803239
#  4 -0.181353  0.252801 -0.365193 -1.930581
#  5 -0.715036  1.128082  0.790161  0.858985
#  6  0.808755  0.276395 -0.201292  0.782164,
#            0         1         2         3
#  7  0.051419  0.931316  0.793594 -0.006051
#  8  2.743267 -0.525389  1.117938  1.621111
#  9  0.307224  0.017265 -0.564946 -0.826756)

# %%
pd.concat([X, Y, Z])
# Out:
#           0         1         2         3
# 0  0.133433 -1.141337 -1.307757 -0.846003
# 1 -0.908109 -0.412874  2.360426  0.521012
# 2 -2.403655 -0.264082  0.264862  0.555531
# 3 -0.235506  1.032290 -0.307916  0.803239
# 4 -0.181353  0.252801 -0.365193 -1.930581
# 5 -0.715036  1.128082  0.790161  0.858985
# 6  0.808755  0.276395 -0.201292  0.782164
# 7  0.051419  0.931316  0.793594 -0.006051
# 8  2.743267 -0.525389  1.117938  1.621111
# 9  0.307224  0.017265 -0.564946 -0.826756

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -0.294878 -0.270781  0.329795 -0.186614
# 1 -0.089158  0.122476  1.764993 -0.613452
# 2 -0.978596  1.250401  0.081330 -1.781929
# 3  0.816636 -0.038603  0.057569 -0.962173
# 4 -0.285464 -1.882319 -0.324812  0.259823
# 5 -0.188646 -0.568057  0.069813  1.051040
# 6  1.294121  0.442027  2.441878  1.440919
# 7  0.064470 -1.182945 -0.205645 -0.285244

# %%
s = df.iloc[3]
s
# Out:
# A    0.816636
# B   -0.038603
# C    0.057569
# D   -0.962173
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.294878 -0.270781  0.329795 -0.186614
# 1 -0.089158  0.122476  1.764993 -0.613452
# 2 -0.978596  1.250401  0.081330 -1.781929
# 3  0.816636 -0.038603  0.057569 -0.962173
# 4 -0.285464 -1.882319 -0.324812  0.259823
# 5 -0.188646 -0.568057  0.069813  1.051040
# 6  1.294121  0.442027  2.441878  1.440919
# 7  0.064470 -1.182945 -0.205645 -0.285244
# 8  0.816636 -0.038603  0.057569 -0.962173

# %% [markdown]
# # Grouping

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.417570  0.430912
# 1  bar    one -0.496397  0.687346
# 2  foo    two  1.255610 -0.925956
# 3  bar  three -0.759403 -0.036117
# 4  foo    two  1.123381 -0.920902
# 5  bar    two  0.213247  0.845642
# 6  foo    one -0.429747 -1.511993
# 7  foo  three -1.648506  1.684720

# %%
df.groupby(['A']).sum()
#df.groupby('A').sum() Prefer to use the syntax above, because that way when you have to add something, it is easier.
# Out:
#             C         D
# A
# bar -1.042553  1.496870
# foo -0.116832 -1.243219

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.496397  0.687346
#     three -0.759403 -0.036117
#     two    0.213247  0.845642
# foo one   -0.847317 -1.081081
#     three -1.648506  1.684720
#     two    2.378991 -1.846858

# %% [markdown]
# # Pandas pivot Table explained:
# http://pbpython.com/pandas-pivot-table-explained.html

# %%
df_pivot = df.pivot_table(values=['C', 'D'], 
              index = ['A'],
               aggfunc = [np.mean],
               columns=['B'],
               fill_value = None) 
df_pivot
# Out:
#          mean
#             C                             D
# B         one     three       two       one     three       two
# A
# bar -0.496397 -0.759403  0.213247  0.687346 -0.036117  0.845642
# foo -0.423658 -1.648506  1.189495 -0.540540  1.684720 -0.923429

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two','one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     0.333189 -0.108492
#       two     1.044630  0.247399
# baz   one    -0.186237 -1.446388
#       two     0.562962 -0.588786

# %%
#df2.stack().unstack(1)
df2.stack().unstack(2)
# Out:
#                      A         B
# first second
# bar   one     0.333189 -0.108492
#       two     1.044630  0.247399
# baz   one    -0.186237 -1.446388
#       two     0.562962 -0.588786

# %%
df2.unstack()
# Out:
#                A                   B
# second       one       two       one       two
# first
# bar     0.333189  1.044630 -0.108492  0.247399
# baz    -0.186237  0.562962 -1.446388 -0.588786

# %%
df = pd.DataFrame({'ColA' : ['one', 'one', 'two', 'three'] * 12,
                   'ColB' : ['A', 'B', 'C'] * 16,
                   'ColC' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 8,
                   'ColD' : np.random.randn(48),
                   'ColE' : np.random.randn(48)})
df.head()
# Out:
#     ColA ColB ColC      ColD      ColE
# 0    one    A  foo  0.435329 -1.682589
# 1    one    B  foo -1.436726  0.378567
# 2    two    C  foo  0.199953  1.821571
# 3  three    A  bar  0.495197  0.797225
# 4    one    B  bar  1.803194  0.559269

# %%
df_pivot = df.pivot_table(values=['ColD', 'ColE'], 
               index=['ColA', 'ColB'], 
               columns=[], 
               aggfunc=[np.mean, np.median, np.min, np.max, np.count_nonzero], 
               #aggfunc={"ColD":np.mean,"ColE":[np.mean, np.median, np.min, np.max, np.count_nonzero]},
               fill_value='', 
               margins=False, 
               dropna=True, 
               margins_name='All')
df_pivot
# Out:
#                 mean              median                amin            \
#                 ColD      ColE      ColD      ColE      ColD      ColE
# ColA  ColB
# one   A     0.121131 -0.269194  0.108107 -0.465671 -1.535532 -1.682589
#       B     0.993655  0.059247  0.972416  0.390717 -1.436726 -1.212081
#       C    -0.015384  0.108594 -0.507486  0.282062 -1.671504 -1.250104
# three A    -0.137290  0.419097  0.328403  0.323178 -1.857785 -0.292422
#       B    -0.869011  0.075673 -1.003393 -0.197339 -1.520219 -0.711577
#       C    -0.268556  0.176772 -0.664761  0.204047 -1.228045 -0.515433
# two   A     0.532258  0.244234  0.192987  0.138211 -0.690622 -0.903181
#       B     0.669839 -0.446303  0.445052  0.133887 -1.004127 -2.418263
#       C     1.009928  0.392699  0.668214  0.058492  0.199953 -0.367759
#
#                 amax           count_nonzero
#                 ColD      ColE          ColD ColE
# ColA  ColB
# one   A     1.432293  2.038108             8    8
#       B     2.823184  0.559269             8    8
#       C     2.928117  1.162552             8    8
# three A     0.651818  1.322454             4    4
#       B     0.050960  1.408945             4    4
#       C     1.483342  0.814426             4    4
# two   A     2.433683  1.603694             4    4
#       B     2.793381  0.365276             4    4
#       C     2.503333  1.821571             4    4

# %%
cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True, center="light")
f, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_pivot,
            cmap=cmap, 
            center=None, 
            robust=False, 
            annot=True, 
            annot_kws=None, 
            linewidths=1, 
            linecolor='white', cbar=True, square=True)

# %% [markdown]
# # Applying style to the dataframe itself:
#     http://pandas.pydata.org/pandas-docs/stable/style.html

# %%
cm = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True, center="light")
s = df_pivot.style.background_gradient(cmap=cm)
s
# Out:
#         <style  type="text/css" >
#
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col0 {
#
#                 background-color:  #fbe7f1;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col1 {
#
#                 background-color:  #6f979d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col2 {
#
#                 background-color:  #f1d5e3;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col3 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col4 {
#
#                 background-color:  #59858c;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col5 {
#
#                 background-color:  #aec9cd;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col6 {
#
#                 background-color:  #eaf8fa;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col7 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col8 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row0_col9 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col0 {
#
#                 background-color:  #8a174f;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col1 {
#
#                 background-color:  #edcddd;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col2 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col3 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col4 {
#
#                 background-color:  #6f979d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col5 {
#
#                 background-color:  #f0d4e2;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col6 {
#
#                 background-color:  #902258;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col7 {
#
#                 background-color:  #46767d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col8 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row1_col9 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col0 {
#
#                 background-color:  #e0f0f3;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col1 {
#
#                 background-color:  #deb2c8;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col2 {
#
#                 background-color:  #84a7ad;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col3 {
#
#                 background-color:  #a64b78;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col4 {
#
#                 background-color:  #3c6e75;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col5 {
#
#                 background-color:  #f5dde9;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col6 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col7 {
#
#                 background-color:  #eaf8fa;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col8 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row2_col9 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col0 {
#
#                 background-color:  #c2d8dc;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col1 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col2 {
#
#                 background-color:  #d7a5be;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col3 {
#
#                 background-color:  #9b3667;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col4 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col5 {
#
#                 background-color:  #88134d;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col6 {
#
#                 background-color:  #71989e;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col7 {
#
#                 background-color:  #f0d2e1;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col8 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row3_col9 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col0 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col1 {
#
#                 background-color:  #e8c4d6;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col2 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col3 {
#
#                 background-color:  #a0bdc2;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col4 {
#
#                 background-color:  #5c878e;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col5 {
#
#                 background-color:  #b76a90;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col6 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col7 {
#
#                 background-color:  #e3bbcf;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col8 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row4_col9 {
#
#                 background-color:  #134e57;
#
#             }
#
#             #T_e56ffc8f_e45a_11e6_968b_185e0f10bbc9row5_col0 {
#
#                 background-color:  #a2bfc3;
#
#             }

# %%
sns.jointplot("ColD", 
              "ColE", 
              data=df, 
              size=5, 
             kind='scatter')

# %%
df_pivot.columns.values
# Out:
# array([('mean', 'ColD'), ('mean', 'ColE'), ('median', 'ColD'),
#        ('median', 'ColE'), ('amin', 'ColD'), ('amin', 'ColE'),
#        ('amax', 'ColD'), ('amax', 'ColE'), ('count_nonzero', 'ColD'),
#        ('count_nonzero', 'ColE')], dtype=object)

# %% [markdown]
# # Trying out various pandas functions:
# The way to try different things is rather two step process.
#
# Look at the pandas documentation for full setup and insturctions.
#
# Go to stack overflow, because that is where you would see amazing examples.

# %%
np.random.seed([3,1415])
n = 1000
df = pd.DataFrame(
    dict(country=np.random.choice(('UK', 'US', 'China'), n),
         source=np.random.choice(('Ads', 'Seo', 'Direct'), n)))

# %%
df.head()
# Out:
#   country  source
# 0      UK  Direct
# 1   China     Seo
# 2   China     Ads
# 3   China     Ads
# 4   China     Ads

# %%
size = df.groupby(['country', 'source']).size().unstack()
size.div(size.sum(1), axis=0)
# Out:
# source        Ads    Direct       Seo
# country
# China    0.330357  0.309524  0.360119
# UK       0.336066  0.333333  0.330601
# US       0.362416  0.355705  0.281879

# %%
pd.qcut(range(20), 3, labels=["good","medium","bad"], )
# Out:
# [good, good, good, good, good, ..., bad, bad, bad, bad, bad]
# Length: 20
# Categories (3, object): [good < medium < bad]

# %% [markdown]
# # Understand what Pd.crosstab does:

# %%
df = pd.DataFrame([['Cat_1', 'Cat_1', 'Cat_2'], 
                   ['Cat_1', 'Cat_2', 'Cat_2'], 
                   ['Cat_2', 'Cat_2', 'Cat_2'], 
                   ['Cat_1', 'Cat_1', 'Cat_1'], 
                   ['Cat_2', 'Cat_1', 'Cat_2']],
                   columns=['A', 'B', 'C'], index=[1, 2, 3, 4, 5])

# %%
df
# Out:
#        A      B      C
# 1  Cat_1  Cat_1  Cat_2
# 2  Cat_1  Cat_2  Cat_2
# 3  Cat_2  Cat_2  Cat_2
# 4  Cat_1  Cat_1  Cat_1
# 5  Cat_2  Cat_1  Cat_2

# %%
df.groupby(['A', 'B']).agg([len])
# Out:
#               C
#             len
# A     B
# Cat_1 Cat_1   2
#       Cat_2   1
# Cat_2 Cat_1   1
#       Cat_2   1

# %%
pd.crosstab(df['A'], df['B'])
# Out:
# B      Cat_1  Cat_2
# A
# Cat_1      2      1
# Cat_2      1      1

# %% [markdown]
# # Rolling mean type of functions:

# %%
df = pd.DataFrame ({'ID' : ['foo', 'bar'] * 10,
                    'ORDER' : np.arange(20),
                    'VAL' : np.random.randn(20)})
df = df.sort_values(['ID','ORDER'])

def expanding_max_mean(x, size=3):
    return np.mean(np.sort(np.array(x))[-size:])

# %%
df['exp_mean'] = df.groupby('ID')['VAL'].apply(lambda x: pd.expanding_apply(x, expanding_max_mean))
# Out:
# C:\Users\rmalshe\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.expanding_apply is deprecated for Series and will be removed in a future version, replace with
# 	Series.expanding(min_periods=1).apply(args=<tuple>,func=<function>,kwargs=<dict>)
#   if __name__ == '__main__':

# %%
df
# Out:
#      ID  ORDER       VAL  exp_mean
# 1   bar      1 -0.232502 -0.232502
# 3   bar      3  0.586329  0.176914
# 5   bar      5 -0.651449 -0.099207
# 7   bar      7  0.193015  0.182281
# 9   bar      9 -0.031734  0.249204
# 11  bar     11 -1.584389  0.249204
# 13  bar     13 -0.660125  0.249204
# 15  bar     15  0.537677  0.439007
# 17  bar     17 -0.365412  0.439007
# 19  bar     19 -1.110639  0.439007
# 0   foo      0 -0.765096 -0.765096
# 2   foo      2  0.038581 -0.363258
# 4   foo      4  0.135966 -0.196850
# 6   foo      6  0.352110  0.175552
# 8   foo      8  0.438932  0.309003
# 10  foo     10  0.775273  0.522105
# 12  foo     12 -0.403137  0.522105
# 14  foo     14 -0.544922  0.522105
# 16  foo     16 -0.069157  0.522105
# 18  foo     18  0.943544  0.719250

# %% [markdown]
# # Essential basic functionality with text data

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.upper()
# Out:
# 0       A
# 1       B
# 2       C
# 3    AABA
# 4    BACA
# 5     NaN
# 6    CABA
# 7     DOG
# 8     CAT
# dtype: object

# %%
s.str.len()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    4.0
# 4    4.0
# 5    NaN
# 6    4.0
# 7    3.0
# 8    3.0
# dtype: float64

# %%
idx = pd.Index([' jack', 'jill     ', '          jesse ', '    frank'])
idx.str.strip()
#idx.str.lstrip()
#idx.str.rstrip()
# Out:
# Index([u'jack', u'jill', u'jesse', u'frank'], dtype='object')

# %%
df = pd.DataFrame(np.random.randn(12))
df.columns=[' Column A ']

# %%
df.columns.values
# Out:
# array([' Column A '], dtype=object)

# %%
df.columns = df.columns.str.strip().str.upper().str.replace(' ', '_')
df.columns.values
# Out:
# array(['COLUMN_A'], dtype=object)

# %%
dollars = pd.Series(['12', '-$10', '$10,000'])

# %%
dollars.str.replace('$', '')
# Out:
# 0        12
# 1       -10
# 2    10,000
# dtype: object

# %%
s = pd.Series(["a1", "b2", "c3"], ["A11", "B22", "C33"])
s.index.str.extract("(?P<letter>[a-zA-Z])", expand=True)
# Out:
#   letter
# 0      A
# 1      B
# 2      C

# %% [markdown]
# # Method Summary
# Method	Description
#
# cat()	Concatenate strings
#
# split()	Split strings on delimiter
#
# rsplit()	Split strings on delimiter working from the end of the string
#
# get()	Index into each element (retrieve i-th element)
#
# join()	Join strings in each element of the Series with passed separator
#
# get_dummies()	Split strings on the delimiter returning DataFrame of dummy variables
#
# contains()	Return boolean array if each string contains pattern/regex
#
# replace()	Replace occurrences of pattern/regex with some other string
#
# repeat()	Duplicate values (s.str.repeat(3) equivalent to x * 3)
#
# pad()	Add whitespace to left, right, or both sides of strings
#
# center()	Equivalent to str.center
#
# ljust()	Equivalent to str.ljust
#
# rjust()	Equivalent to str.rjust
#
# zfill()	Equivalent to str.zfill
#
# wrap()	Split long strings into lines with length less than a given width
#
# slice()	Slice each string in the Series
#
# slice_replace()	Replace slice in each string with passed value
#
# count()	Count occurrences of pattern
#
# startswith()	Equivalent to str.startswith(pat) for each element
#
# endswith()	Equivalent to str.endswith(pat) for each element
#
# findall()	Compute list of all occurrences of pattern/regex for each string
#
# match()	Call re.match on each element, returning matched groups as list
#
# extract()	Call re.search on each element, returning DataFrame with one row for each element and one column for each regex
#
# capture group
#
# extractall()	Call re.findall on each element, returning DataFrame with one row for each match and one column for each regex
#
# capture group
#
# len()	Compute string lengths
#
# strip()	Equivalent to str.strip
#
# rstrip()	Equivalent to str.rstrip
#
# lstrip()	Equivalent to str.lstrip
#
# partition()	Equivalent to str.partition
#
# rpartition()	Equivalent to str.rpartition
#
# lower()	Equivalent to str.lower
#
# upper()	Equivalent to str.upper
#
# find()	Equivalent to str.find
#
# rfind()	Equivalent to str.rfind
#
# index()	Equivalent to str.index
#
# rindex()	Equivalent to str.rindex
#
# capitalize()	Equivalent to str.capitalize
#
# swapcase()	Equivalent to str.swapcase
#
# normalize()	Return Unicode normal form. Equivalent to unicodedata.normalize
#
# translate()	Equivalent to str.translate
#
# isalnum()	Equivalent to str.isalnum
#
# isalpha()	Equivalent to str.isalpha
#
# isdigit()	Equivalent to str.isdigit
#
# isspace()	Equivalent to str.isspace
#
# islower()	Equivalent to str.islower
#
# isupper()	Equivalent to str.isupper
#
# istitle()	Equivalent to str.istitle
#
# isnumeric()	Equivalent to str.isnumeric
#
# isdecimal()	Equivalent to str.isdecimal

# %% [markdown]
# # Options and settings:
# A lot of options exist, which readers can check in examples, but a basic functional option use is given below:
# http://pandas.pydata.org/pandas-docs/stable/options.html
#
# An example is of display:

# %%
pd.options.display.max_rows
# Out:
# 100

# %% [markdown]
# # Lambda, Map, Reduce, Filter

# %%
max_xy = lambda x,y: x if x > y else y 
print(max_xy(5,2))
5
# Out:
# 5
# 5

# %%
n = [1,2,3,4, 5, 6, 7, 8]
print((map(lambda x:x*x*x + x**2 + 2, n)))
# Out:
# [4, 14, 38, 82, 152, 254, 394, 578]

# %%
n = [1,2,3,4]
print(reduce (lambda x,y: x*y, n))
# Out:
# 24

# %%
n = [1,2,3,4]
print (list(filter(lambda x: x > 2, n)))
# Out:
# [3, 4]

# %% [markdown]
# # Check out more tutorials on Pandas website where they also show how to use iPython notebook more effectively.

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/tutorials.html

# %% [markdown]
# # Comparisons between R and Python.

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/comparison_with_r.html

# %% [markdown]
# # Now some real work! Dealing with the ugly Data-set

# %% [markdown]
# I downloaded data from various sources, and then merged them so as to come up with a wide variety of columns.
#
# I call it the Ugly Data-set. If you can deal with this, you can deal with any type of Data-set.

# %%
df = pd.read_csv(path+'test.csv')

# %%
df.head(2).T
# Out:
#                                                                                                            0  \
# Id                                                                                                      1461
# MSSubClass                                                                                                20
# MSZoning                                                                                                  RH
# LotFrontage                                                                                               80
# LotArea                                                                                                11622
# Street                                                                                                  Pave
# Alley                                                                                                    NaN
# LotShape                                                                                                 Reg
# LandContour                                                                                              Lvl
# Utilities                                                                                             AllPub
# LotConfig                                                                                             Inside
# LandSlope                                                                                                Gtl
# Neighborhood                                                                                           NAmes
# Condition1                                                                                             Feedr
# Condition2                                                                                              Norm
# BldgType                                                                                                1Fam
# HouseStyle                                                                                            1Story
# OverallQual                                                                                                5
# OverallCond                                                                                                6
# YearBuilt                                                                                               1961
# YearRemodAdd                                                                                            1961
# RoofStyle                                                                                              Gable
# RoofMatl                                                                                             CompShg
# Exterior1st                                                                                          VinylSd
# Exterior2nd                                                                                          VinylSd
# MasVnrType                                                                                              None
# MasVnrArea                                                                                                 0
# ExterQual                                                                                                 TA
# ExterCond                                                                                                 TA
# Foundation                                                                                            CBlock
# BsmtQual                                                                                                  TA
# BsmtCond                                                                                                  TA
# BsmtExposure                                                                                              No
# BsmtFinType1                                                                                             Rec
# BsmtFinSF1                                                                                               468
# BsmtFinType2                                                                                             LwQ
# BsmtFinSF2                                                                                               144
# BsmtUnfSF                                                                                                270
# TotalBsmtSF                                                                                              882
# Heating                                                                                                 GasA
# HeatingQC                                                                                                 TA
# CentralAir                                                                                                 Y
# Electrical                                                                                             SBrkr
# 1stFlrSF                                                                                                 896
# 2ndFlrSF                                                                                                   0
# LowQualFinSF                                                                                               0
# GrLivArea                                                                                                896
# BsmtFullBath                                                                                               0
# BsmtHalfBath                                                                                               0
# FullBath                                                                                                   1
# HalfBath                                                                                                   0
# BedroomAbvGr                                                                                               2
# KitchenAbvGr                                                                                               1
# KitchenQual                                                                                               TA
# TotRmsAbvGrd                                                                                               5
# Functional                                                                                               Typ
# Fireplaces                                                                                                 0
# FireplaceQu                                                                                              NaN
# GarageType                                                                                            Attchd
# GarageYrBlt                                                                                             1961
# GarageFinish                                                                                             Unf
# GarageCars                                                                                                 1
# GarageArea                                                                                               730
# GarageQual                                                                                                TA
# GarageCond                                                                                                TA
# PavedDrive                                                                                                 Y
# WoodDeckSF                                                                                               140
# OpenPorchSF                                                                                                0
# EnclosedPorch                                                                                              0
# 3SsnPorch                                                                                                  0
# ScreenPorch                                                                                              120
# PoolArea                                                                                                   0
# PoolQC                                                                                                   NaN
# Fence                                                                                                  MnPrv
# MiscFeature                                                                                              NaN
# MiscVal                                                                                                    0
# MoSold                                                                                                     6
# YrSold                                                                                                  2010
# SaleType                                                                                                  WD
# SaleCondition                                                                                         Normal
# Owner                                                                               BIN SALIMII, AIDIL ADHAR
# DateRemodeled                                                                                1/12/2017 20:05
# DateSecondRemodel                                                                            5/21/2016 20:09
# InspectionDetails                                 CURR_COND=AVG;INSP_PROC=MG;RMLS_APPROVED=YES;HOI_INCL=INCL
# Manager_Price_RiseInPrice                     MANAGER=self;Price=169277.0524984;RiseInPrice=5912.67863388541
# Comment                    Inside, the living room claims carpet, ample windows, & stylish corner fireplace.
#
#                                                                                                                                                                                                                                                                         1
# Id                                                                                                                                                                                                                                                                   1462
# MSSubClass                                                                                                                                                                                                                                                             20
# MSZoning                                                                                                                                                                                                                                                               RL
# LotFrontage                                                                                                                                                                                                                                                            81
# LotArea                                                                                                                                                                                                                                                             14267
# Street                                                                                                                                                                                                                                                               Pave
# Alley                                                                                                                                                                                                                                                                 NaN
# LotShape                                                                                                                                                                                                                                                              IR1
# LandContour                                                                                                                                                                                                                                                           Lvl
# Utilities                                                                                                                                                                                                                                                          AllPub
# LotConfig                                                                                                                                                                                                                                                          Corner
# LandSlope                                                                                                                                                                                                                                                             Gtl
# Neighborhood                                                                                                                                                                                                                                                        NAmes
# Condition1                                                                                                                                                                                                                                                           Norm
# Condition2                                                                                                                                                                                                                                                           Norm
# BldgType                                                                                                                                                                                                                                                             1Fam
# HouseStyle                                                                                                                                                                                                                                                         1Story
# OverallQual                                                                                                                                                                                                                                                             6
# OverallCond                                                                                                                                                                                                                                                             6
# YearBuilt                                                                                                                                                                                                                                                            1958
# YearRemodAdd                                                                                                                                                                                                                                                         1958
# RoofStyle                                                                                                                                                                                                                                                             Hip
# RoofMatl                                                                                                                                                                                                                                                          CompShg
# Exterior1st                                                                                                                                                                                                                                                       Wd Sdng
# Exterior2nd                                                                                                                                                                                                                                                       Wd Sdng
# MasVnrType                                                                                                                                                                                                                                                        BrkFace
# MasVnrArea                                                                                                                                                                                                                                                            108
# ExterQual                                                                                                                                                                                                                                                              TA
# ExterCond                                                                                                                                                                                                                                                              TA
# Foundation                                                                                                                                                                                                                                                         CBlock
# BsmtQual                                                                                                                                                                                                                                                               TA
# BsmtCond                                                                                                                                                                                                                                                               TA
# BsmtExposure                                                                                                                                                                                                                                                           No
# BsmtFinType1                                                                                                                                                                                                                                                          ALQ
# BsmtFinSF1                                                                                                                                                                                                                                                            923
# BsmtFinType2                                                                                                                                                                                                                                                          Unf
# BsmtFinSF2                                                                                                                                                                                                                                                              0
# BsmtUnfSF                                                                                                                                                                                                                                                             406
# TotalBsmtSF                                                                                                                                                                                                                                                          1329
# Heating                                                                                                                                                                                                                                                              GasA
# HeatingQC                                                                                                                                                                                                                                                              TA
# CentralAir                                                                                                                                                                                                                                                              Y
# Electrical                                                                                                                                                                                                                                                          SBrkr
# 1stFlrSF                                                                                                                                                                                                                                                             1329
# 2ndFlrSF                                                                                                                                                                                                                                                                0
# LowQualFinSF                                                                                                                                                                                                                                                            0
# GrLivArea                                                                                                                                                                                                                                                            1329
# BsmtFullBath                                                                                                                                                                                                                                                            0
# BsmtHalfBath                                                                                                                                                                                                                                                            0
# FullBath                                                                                                                                                                                                                                                                1
# HalfBath                                                                                                                                                                                                                                                                1
# BedroomAbvGr                                                                                                                                                                                                                                                            3
# KitchenAbvGr                                                                                                                                                                                                                                                            1
# KitchenQual                                                                                                                                                                                                                                                            Gd
# TotRmsAbvGrd                                                                                                                                                                                                                                                            6
# Functional                                                                                                                                                                                                                                                            Typ
# Fireplaces                                                                                                                                                                                                                                                              0
# FireplaceQu                                                                                                                                                                                                                                                           NaN
# GarageType                                                                                                                                                                                                                                                         Attchd
# GarageYrBlt                                                                                                                                                                                                                                                          1958
# GarageFinish                                                                                                                                                                                                                                                          Unf
# GarageCars                                                                                                                                                                                                                                                              1
# GarageArea                                                                                                                                                                                                                                                            312
# GarageQual                                                                                                                                                                                                                                                             TA
# GarageCond                                                                                                                                                                                                                                                             TA
# PavedDrive                                                                                                                                                                                                                                                              Y
# WoodDeckSF                                                                                                                                                                                                                                                            393
# OpenPorchSF                                                                                                                                                                                                                                                            36
# EnclosedPorch                                                                                                                                                                                                                                                           0
# 3SsnPorch                                                                                                                                                                                                                                                               0
# ScreenPorch                                                                                                                                                                                                                                                             0
# PoolArea                                                                                                                                                                                                                                                                0
# PoolQC                                                                                                                                                                                                                                                                NaN
# Fence                                                                                                                                                                                                                                                                 NaN
# MiscFeature                                                                                                                                                                                                                                                          Gar2
# MiscVal                                                                                                                                                                                                                                                             12500
# MoSold                                                                                                                                                                                                                                                                  6
# YrSold                                                                                                                                                                                                                                                               2010
# SaleType                                                                                                                                                                                                                                                               WD
# SaleCondition                                                                                                                                                                                                                                                      Normal
# Owner                                                                                                                                                                                                                                                    LEONG, BOON HOCK
# DateRemodeled                                                                                                                                                                                                                                             1/12/2017 20:35
# DateSecondRemodel                                                                                                                                                                                                                                         6/17/2016 10:46
# InspectionDetails                                                                                                                                                                                           CURR_COND=GOOD;INSP_PROC=NA;RMLS_APPROVED=YES;HOI_INCL=NOTINC
# Manager_Price_RiseInPrice                                                                                                                                                                                 MANAGER=hoa;Price=187758.393988768;RiseInPrice=12571.9613809518
# Comment                    Beautifully remodeled building on high traffic intersection, zoned Commercial OC, Also grandfathered residential could be used residential as well. Building updated throughout, new roof, electrical, all interior finishes, fully insulated.

# %%
df.describe().T
# Out:
#                 count         mean          std     min     25%     50%  \
# Id             1459.0  2190.000000   421.321334  1461.0  1825.5  2190.0
# MSSubClass     1459.0    57.378341    42.746880    20.0    20.0    50.0
# LotFrontage    1232.0    68.580357    22.376841    21.0     NaN     NaN
# LotArea        1459.0  9819.161069  4955.517327  1470.0  7391.0  9399.0
# OverallQual    1459.0     6.078821     1.436812     1.0     5.0     6.0
# OverallCond    1459.0     5.553804     1.113740     1.0     5.0     5.0
# YearBuilt      1459.0  1971.357779    30.390071  1879.0  1953.0  1973.0
# YearRemodAdd   1459.0  1983.662783    21.130467  1950.0  1963.0  1992.0
# MasVnrArea     1444.0   100.709141   177.625900     0.0     NaN     NaN
# BsmtFinSF1     1458.0   439.203704   455.268042     0.0     NaN     NaN
# BsmtFinSF2     1458.0    52.619342   176.753926     0.0     NaN     NaN
# BsmtUnfSF      1458.0   554.294925   437.260486     0.0     NaN     NaN
# TotalBsmtSF    1458.0  1046.117970   442.898624     0.0     NaN     NaN
# 1stFlrSF       1459.0  1156.534613   398.165820   407.0   873.5  1079.0
# 2ndFlrSF       1459.0   325.967786   420.610226     0.0     0.0     0.0
# LowQualFinSF   1459.0     3.543523    44.043251     0.0     0.0     0.0
# GrLivArea      1459.0  1486.045922   485.566099   407.0  1117.5  1432.0
# BsmtFullBath   1457.0     0.434454     0.530648     0.0     NaN     NaN
# BsmtHalfBath   1457.0     0.065202     0.252468     0.0     NaN     NaN
# FullBath       1459.0     1.570939     0.555190     0.0     1.0     2.0
# HalfBath       1459.0     0.377656     0.503017     0.0     0.0     0.0
# BedroomAbvGr   1459.0     2.854010     0.829788     0.0     2.0     3.0
# KitchenAbvGr   1459.0     1.042495     0.208472     0.0     1.0     1.0
# TotRmsAbvGrd   1459.0     6.385195     1.508895     3.0     5.0     6.0
# Fireplaces     1459.0     0.581220     0.647420     0.0     0.0     0.0
# GarageYrBlt    1381.0  1977.721217    26.431175  1895.0     NaN     NaN
# GarageCars     1458.0     1.766118     0.775945     0.0     NaN     NaN
# GarageArea     1458.0   472.768861   217.048611     0.0     NaN     NaN
# WoodDeckSF     1459.0    93.174777   127.744882     0.0     0.0     0.0
# OpenPorchSF    1459.0    48.313914    68.883364     0.0     0.0    28.0
# EnclosedPorch  1459.0    24.243317    67.227765     0.0     0.0     0.0
# 3SsnPorch      1459.0     1.794380    20.207842     0.0     0.0     0.0
# ScreenPorch    1459.0    17.064428    56.609763     0.0     0.0     0.0
# PoolArea       1459.0     1.744345    30.491646     0.0     0.0     0.0
# MiscVal        1459.0    58.167923   630.806978     0.0     0.0     0.0
# MoSold         1459.0     6.104181     2.722432     1.0     4.0     6.0
# YrSold         1459.0  2007.769705     1.301740  2006.0  2007.0  2008.0
#
#                    75%      max
# Id              2554.5   2919.0
# MSSubClass        70.0    190.0
# LotFrontage        NaN    200.0
# LotArea        11517.5  56600.0
# OverallQual        7.0     10.0
# OverallCond        6.0      9.0
# YearBuilt       2001.0   2010.0
# YearRemodAdd    2004.0   2010.0
# MasVnrArea         NaN   1290.0
# BsmtFinSF1         NaN   4010.0
# BsmtFinSF2         NaN   1526.0
# BsmtUnfSF          NaN   2140.0
# TotalBsmtSF        NaN   5095.0
# 1stFlrSF        1382.5   5095.0
# 2ndFlrSF         676.0   1862.0
# LowQualFinSF       0.0   1064.0
# GrLivArea       1721.0   5095.0
# BsmtFullBath       NaN      3.0
# BsmtHalfBath       NaN      2.0
# FullBath           2.0      4.0
# HalfBath           1.0      2.0
# BedroomAbvGr       3.0      6.0
# KitchenAbvGr       1.0      2.0
# TotRmsAbvGrd       7.0     15.0
# Fireplaces         1.0      4.0
# GarageYrBlt        NaN   2207.0
# GarageCars         NaN      5.0
# GarageArea         NaN   1488.0
# WoodDeckSF       168.0   1424.0
# OpenPorchSF       72.0    742.0
# EnclosedPorch      0.0   1012.0
# 3SsnPorch          0.0    360.0
# ScreenPorch        0.0    576.0
# PoolArea           0.0    800.0
# MiscVal            0.0  17000.0
# MoSold             8.0     12.0
# YrSold          2009.0   2010.0

# %%
df.columns.values
# Out:
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch',
#        'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold',
#        'YrSold', 'SaleType', 'SaleCondition', 'Owner', 'DateRemodeled',
#        'DateSecondRemodel', 'InspectionDetails',
#        'Manager_Price_RiseInPrice', 'Comment'], dtype=object)

# %%
df.loc[0:1,['InspectionDetails']].head()
# Out:
#                                                InspectionDetails
# 0     CURR_COND=AVG;INSP_PROC=MG;RMLS_APPROVED=YES;HOI_INCL=INCL
# 1  CURR_COND=GOOD;INSP_PROC=NA;RMLS_APPROVED=YES;HOI_INCL=NOTINC

# %%
df.loc[df.Fence.isin(['MnPrv']),['Id', 'MSSubClass', 'Comment']].head()
# Out:
#       Id  MSSubClass  \
# 0   1461          20
# 2   1463          60
# 9   1470          20
# 58  1519          20
# 71  1532          30
#
#                                                                                                                                                                                                                                            Comment
# 0                                                                                                                                                                Inside, the living room claims carpet, ample windows, & stylish corner fireplace.
# 2                                                                                                                                                                Inside, the living room claims carpet, ample windows, & stylish corner fireplace.
# 9                                                                                                                                            This daylight ranch has it all. Pull up to a neat facade, where a 2-car garage offers great utility.�
# 58  Beautifully remodeled building on high traffic intersection, zoned Commercial OC, Also grandfathered residential could be used residential as well. Building updated throughout, new roof, electrical, all interior finishes, fully insulated.
# 71                                                                                                                                                               Inside, the living room claims carpet, ample windows, & stylish corner fireplace.

# %%
df['CURR_COND'], df['INSP_PROC'], df['RMLS_APPROVED'], df['HOI_INCL'] = zip(*df['InspectionDetails'].str.split(";").tolist())
df['junk'], df['CURR_COND']     = zip(*df['CURR_COND'].str.split("=").tolist())
df['junk'], df['INSP_PROC']     = zip(*df['INSP_PROC'].str.split("=").tolist())
df['junk'], df['RMLS_APPROVED'] = zip(*df['RMLS_APPROVED'].str.split("=").tolist())
df['junk'], df['HOI_INCL']      = zip(*df['HOI_INCL'].str.split("=").tolist())

# %%
df['MANAGER'], df['Price'], df['RiseInPrice']= zip(*df['Manager_Price_RiseInPrice'].str.split(";").tolist())
df['junk'], df['MANAGER']     = zip(*df['MANAGER'].str.split("=").tolist())
df['junk'], df['Price']       = zip(*df['Price'].str.split("=").tolist())
df['junk'], df['RiseInPrice'] = zip(*df['RiseInPrice'].str.split("=").tolist())

# %%
df['Price'] = pd.to_numeric(df['Price'])
df['RiseInPrice'] = pd.to_numeric(df['RiseInPrice'])

# %%
df.select_dtypes(include=['float64', 'int64']).columns.values
# Out:
# array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'Price', 'RiseInPrice'], dtype=object)

# %%
df.select_dtypes(include=['int64', 'float64']).columns.values
# Out:
# array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'Price', 'RiseInPrice'], dtype=object)

# %%
corr = df.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:].corr()
plt.figure(figsize=(20, 20))
cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True, center="light")
sns.heatmap(corr, vmax=1, square=True, cmap=cmap)

# %%
test = df
# Handle missing values for features where median/mean or most common value doesn't make sense

# Alley : data description says NA means "no alley access"
test.loc[:, "Alley"] = test.loc[:, "Alley"].fillna("None")
# BedroomAbvGr : NA most likely means 0
test.loc[:, "BedroomAbvGr"] = test.loc[:, "BedroomAbvGr"].fillna(0)
# BsmtQual etc : data description says NA for basement features is "no basement"
test.loc[:, "BsmtQual"] = test.loc[:, "BsmtQual"].fillna("No")
test.loc[:, "BsmtCond"] = test.loc[:, "BsmtCond"].fillna("No")
test.loc[:, "BsmtExposure"] = test.loc[:, "BsmtExposure"].fillna("No")
test.loc[:, "BsmtFinType1"] = test.loc[:, "BsmtFinType1"].fillna("No")
test.loc[:, "BsmtFinType2"] = test.loc[:, "BsmtFinType2"].fillna("No")
test.loc[:, "BsmtFullBath"] = test.loc[:, "BsmtFullBath"].fillna(0)
test.loc[:, "BsmtHalfBath"] = test.loc[:, "BsmtHalfBath"].fillna(0)
test.loc[:, "BsmtUnfSF"] = test.loc[:, "BsmtUnfSF"].fillna(0)
# CentralAir : NA most likely means No
test.loc[:, "CentralAir"] = test.loc[:, "CentralAir"].fillna("N")
# Condition : NA most likely means Normal
test.loc[:, "Condition1"] = test.loc[:, "Condition1"].fillna("Norm")
test.loc[:, "Condition2"] = test.loc[:, "Condition2"].fillna("Norm")
# EnclosedPorch : NA most likely means no enclosed porch
test.loc[:, "EnclosedPorch"] = test.loc[:, "EnclosedPorch"].fillna(0)
# External stuff : NA most likely means average
test.loc[:, "ExterCond"] = test.loc[:, "ExterCond"].fillna("TA")
test.loc[:, "ExterQual"] = test.loc[:, "ExterQual"].fillna("TA")
# Fence : data description says NA means "no fence"
test.loc[:, "Fence"] = test.loc[:, "Fence"].fillna("No")
# FireplaceQu : data description says NA means "no fireplace"
test.loc[:, "FireplaceQu"] = test.loc[:, "FireplaceQu"].fillna("No")
test.loc[:, "Fireplaces"] = test.loc[:, "Fireplaces"].fillna(0)
# Functional : data description says NA means typical
test.loc[:, "Functional"] = test.loc[:, "Functional"].fillna("Typ")
# GarageType etc : data description says NA for garage features is "no garage"
test.loc[:, "GarageType"] = test.loc[:, "GarageType"].fillna("No")
test.loc[:, "GarageFinish"] = test.loc[:, "GarageFinish"].fillna("No")
test.loc[:, "GarageQual"] = test.loc[:, "GarageQual"].fillna("No")
test.loc[:, "GarageCond"] = test.loc[:, "GarageCond"].fillna("No")
test.loc[:, "GarageArea"] = test.loc[:, "GarageArea"].fillna(0)
test.loc[:, "GarageCars"] = test.loc[:, "GarageCars"].fillna(0)
# HalfBath : NA most likely means no half baths above grade
test.loc[:, "HalfBath"] = test.loc[:, "HalfBath"].fillna(0)
# HeatingQC : NA most likely means typical
test.loc[:, "HeatingQC"] = test.loc[:, "HeatingQC"].fillna("TA")
# KitchenAbvGr : NA most likely means 0
test.loc[:, "KitchenAbvGr"] = test.loc[:, "KitchenAbvGr"].fillna(0)
# KitchenQual : NA most likely means typical
test.loc[:, "KitchenQual"] = test.loc[:, "KitchenQual"].fillna("TA")
# LotFrontage : NA most likely means no lot frontage
test.loc[:, "LotFrontage"] = test.loc[:, "LotFrontage"].fillna(0)
# LotShape : NA most likely means regular
test.loc[:, "LotShape"] = test.loc[:, "LotShape"].fillna("Reg")
# MasVnrType : NA most likely means no veneer
test.loc[:, "MasVnrType"] = test.loc[:, "MasVnrType"].fillna("None")
test.loc[:, "MasVnrArea"] = test.loc[:, "MasVnrArea"].fillna(0)
# MiscFeature : data description says NA means "no misc feature"
test.loc[:, "MiscFeature"] = test.loc[:, "MiscFeature"].fillna("No")
test.loc[:, "MiscVal"] = test.loc[:, "MiscVal"].fillna(0)
# OpenPorchSF : NA most likely means no open porch
test.loc[:, "OpenPorchSF"] = test.loc[:, "OpenPorchSF"].fillna(0)
# PavedDrive : NA most likely means not paved
test.loc[:, "PavedDrive"] = test.loc[:, "PavedDrive"].fillna("N")
# PoolQC : data description says NA means "no pool"
test.loc[:, "PoolQC"] = test.loc[:, "PoolQC"].fillna("No")
test.loc[:, "PoolArea"] = test.loc[:, "PoolArea"].fillna(0)
# SaleCondition : NA most likely means normal sale
test.loc[:, "SaleCondition"] = test.loc[:, "SaleCondition"].fillna("Normal")
# ScreenPorch : NA most likely means no screen porch
test.loc[:, "ScreenPorch"] = test.loc[:, "ScreenPorch"].fillna(0)
# TotRmsAbvGrd : NA most likely means 0
test.loc[:, "TotRmsAbvGrd"] = test.loc[:, "TotRmsAbvGrd"].fillna(0)
# Utilities : NA most likely means all public utilities
test.loc[:, "Utilities"] = test.loc[:, "Utilities"].fillna("AllPub")
# WoodDeckSF : NA most likely means no wood deck
test.loc[:, "WoodDeckSF"] = test.loc[:, "WoodDeckSF"].fillna(0)

# Some numerical features are actually really categories
test = test.replace({"MSSubClass" : {20 : "SC20", 30 : "SC30", 40 : "SC40", 45 : "SC45", 
                                       50 : "SC50", 60 : "SC60", 70 : "SC70", 75 : "SC75", 
                                       80 : "SC80", 85 : "SC85", 90 : "SC90", 120 : "SC120", 
                                       150 : "SC150", 160 : "SC160", 180 : "SC180", 190 : "SC190"},
                       "MoSold" : {1 : "Jan", 2 : "Feb", 3 : "Mar", 4 : "Apr", 5 : "May", 6 : "Jun",
                                   7 : "Jul", 8 : "Aug", 9 : "Sep", 10 : "Oct", 11 : "Nov", 12 : "Dec"}
                      })

# Encode some categorical features as ordered numbers when there is information in the order
test = test.replace({"Alley" : {"Grvl" : 1, "Pave" : 2},
                       "BsmtCond" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "BsmtExposure" : {"No" : 0, "Mn" : 1, "Av": 2, "Gd" : 3},
                       "BsmtFinType1" : {"No" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, 
                                         "ALQ" : 5, "GLQ" : 6},
                       "BsmtFinType2" : {"No" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, 
                                         "ALQ" : 5, "GLQ" : 6},
                       "BsmtQual" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA": 3, "Gd" : 4, "Ex" : 5},
                       "ExterCond" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "ExterQual" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "FireplaceQu" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "Functional" : {"Sal" : 1, "Sev" : 2, "Maj2" : 3, "Maj1" : 4, "Mod": 5, 
                                       "Min2" : 6, "Min1" : 7, "Typ" : 8},
                       "GarageCond" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "GarageQual" : {"No" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "HeatingQC" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "KitchenQual" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "LandSlope" : {"Sev" : 1, "Mod" : 2, "Gtl" : 3},
                       "LotShape" : {"IR3" : 1, "IR2" : 2, "IR1" : 3, "Reg" : 4},
                       "PavedDrive" : {"N" : 0, "P" : 1, "Y" : 2},
                       "PoolQC" : {"No" : 0, "Fa" : 1, "TA" : 2, "Gd" : 3, "Ex" : 4},
                       "Street" : {"Grvl" : 1, "Pave" : 2},
                       "Utilities" : {"ELO" : 1, "NoSeWa" : 2, "NoSewr" : 3, "AllPub" : 4}}
                      )

# %%
corr = test.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:].corr()
plt.figure(figsize=(20, 20))
cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True, center="light")
sns.heatmap(corr, vmax=1, square=True, cmap=cmap)
