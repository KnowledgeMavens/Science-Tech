# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
daily_stats = {'Day':['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
               'Sleeping':[10,7,5,7,9],
               'Exercise':[.30,.40,.45,.70,.35],
               'Working':[6,4,2,10,7]}

# %%
print(daily_stats)
# Out:
# {'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], 'Sleeping': [10, 7, 5, 7, 9], 'Exercise': [0.3, 0.4, 0.45, 0.7, 0.35], 'Working': [6, 4, 2, 10, 7]}

# %%
df = pd.DataFrame(daily_stats)

# %%
df
# Out:
#          Day  Exercise  Sleeping  Working
# 0     Monday      0.30        10        6
# 1    Tuesday      0.40         7        4
# 2  Wednesday      0.45         5        2
# 3   Thursday      0.70         7       10
# 4     Friday      0.35         9        7

# %%
df.set_index('Day',inplace=True)

# %%
df
# Out:
#            Exercise  Sleeping  Working
# Day
# Monday         0.30        10        6
# Tuesday        0.40         7        4
# Wednesday      0.45         5        2
# Thursday       0.70         7       10
# Friday         0.35         9        7

# %%
df['Exercise'].plot()
plt.show()

# %%
df.plot()
plt.show()
